# %%
n = 6
m = 10

# Use {n} and {m} to pass the values 10 and 20 to the command
!geng {n} {m}:{m} > graphs_n{n}_m{m}.g6
# Out:
# >A geng -d0D5 n=6 e=10
# >Z 15 graphs generated in 0.00 sec

# %%
# Count lines in the file (each line is one graph)
!wc -l graphs_n10_m20.g6
# Out:
# 1061159 graphs_n10_m20.g6
