# %%
with open(graph9.g6.1) as fh:
    for line in fh:
      line = line.strip()
      if not line:
        continue
      H = Graph(line, format='graph6')
      H.show()
      break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open(graph9.g6.gen(1)) as fh:
#       2     for line in fh:
#       3       line = line.strip()
#
# NameError: name 'graph9' is not defined

# %%
# Create an empty list to store the graphs
graphs_list = []

# Open the file (make sure to use quotes around the filename)
with open('graph9.g6', 'r') as fh:
    for line in fh:
        line = line.strip()
        if not line: continue
        
        # Add graph to the list
        graphs_list.append(Graph(line))
        
        # Stop once we have 10 graphs
        if len(graphs_list) >= 10:
            break

# Display them all at once in a grid (5 columns wide)
graphics_array([g.plot(vertex_size=30, vertex_labels=False) for g in graphs_list], ncols=5).show()
# Out:
# Graphics Array of size 2 x 5

# %%
# !geng 10 20:20 > graphs_n10_m20.g6
# Out:
# >A geng -d0D9 n=10 e=20
# >Z 1061159 graphs generated in 0.37 sec
