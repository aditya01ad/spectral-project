# %%
"""
One of the most powerful tools for this is the Cauchy Interlacing 
Theorem. It states that the eigenvalues of any induced subgraph "interlace" 
the eigenvalues of the original graph. In simple terms, this means that the 
largest eigenvalue of an induced subgraph can be no larger than the largest 
eigenvalue of the whole graph.

This is incredibly useful for creating "forbidden subgraph" arguments. For 
example, the proof that the path graph, Pn​, is DS relies on this. A key step 
is to show that any graph cospectral to Pn​ must be a tree.
"""

# %%
# Thelargest eigenvalu of any cycle graph C_k is exectly 2.
C5 = graphs.CycleGraph(5)
C5_max_eig = max(C5.spectrum())
print(f"Largest eigenvalue of C5 : {C5_max_eig}")

# The largest eigenvalue of any grph P_n is always less than 2.
P5 = graphs.PathGraph(5)
P5_max_eig = max(P5.spectrum())
print(f"Largest eigenvelue of P5 : {P5_max_eig}")
# Out:
# Largest eigenvalue of C5 : 2
# Largest eigenvelue of P5 : 1.732050807568878?
